# %% [markdown]
# # **This notebook was created with the goal of exploring que dataset**

# %%
import pandas as pd

df = pd.read_csv('../data/TMDB_movie_dataset_v11.csv')

print(f'Shape: {df.shape}')

df
# Out:
# Shape: (1209666, 24)
#               id                                              title  \
# 0          27205                                          Inception
# 1         157336                                       Interstellar
# 2            155                                    The Dark Knight
# 3          19995                                             Avatar
# 4          24428                                       The Avengers
# ...          ...                                                ...
# 1209661   768517  Sacred Cow: The Nutritional, Environmental and...
# 1209662   768518                             Horské volání S. O. S.
# 1209663   768519                             Frau Annas Pilgerfahrt
# 1209664   768521                          Der provisorische Ehemann
# 1209665  1466328                              The Demolition Lovers
#
#          vote_average  vote_count    status release_date     revenue  runtime  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1209666 entries, 0 to 1209665
# Data columns (total 24 columns):
#  #   Column                Non-Null Count    Dtype
# ---  ------                --------------    -----
#  0   id                    1209666 non-null  int64
#  1   title                 1209653 non-null  object
#  2   vote_average          1209666 non-null  float64
#  3   vote_count            1209666 non-null  int64
#  4   status                1209666 non-null  object
#  5   release_date          991034 non-null   object
#  6   revenue               1209666 non-null  int64
#  7   runtime               1209666 non-null  int64
#  8   adult                 1209666 non-null  bool
#  9   backdrop_path         315416 non-null   object
#  10  budget                1209666 non-null  int64
#  11  homepage              127122 non-null   object
#  12  imdb_id               619692 non-null   object
#  13  original_language     1209666 non-null  object
# ...

# %%
sample = df['genres'].dropna().iloc[0]
print(sample)
sample
# Out:
# Action, Science Fiction, Adventure
# 'Action, Science Fiction, Adventure'

# %%
columns_to_keep = [
    "id",
    "title",
    "release_date",
    "vote_average",
    "vote_count",
    "status",
    "runtime",
    "adult",
    "budget",
    "revenue",
    "original_language",
    "popularity",
    "genres"
]

df_clean = df[columns_to_keep].copy()

# %%
# Removes movies without title or genre
df_clean.dropna(subset=['title', 'genres'], inplace=True)

# Convert date from string to datetime
df_clean['release_date'] = pd.to_datetime(df_clean['release_date'], errors='coerce')

# Removes invalid dates
df_clean = df_clean[df_clean['release_date'].notnull()]
print(df_clean['release_date'].notnull())
# Out:
# 0          True
# 1          True
# 2          True
# 3          True
# 4          True
#            ...
# 1209657    True
# 1209659    True
# 1209661    True
# 1209662    True
# 1209664    True
# Name: release_date, Length: 665260, dtype: bool

# %%
print(df_clean.shape)
print(df_clean.isnull().sum())
print(df_clean.head(3))
# Out:
# (665260, 13)
# id                   0
# title                0
# release_date         0
# vote_average         0
# vote_count           0
# status               0
# runtime              0
# adult                0
# budget               0
# revenue              0
# original_language    0
# popularity           0
# genres               0
# dtype: int64
#        id            title release_date  vote_average  vote_count    status  \
# 0   27205        Inception   2010-07-15         8.364       34495  Released
# 1  157336     Interstellar   2014-11-05         8.417       32571  Released
# 2     155  The Dark Knight   2008-07-16         8.512       30619  Released
#
#    runtime  adult     budget     revenue original_language  popularity  \
# 0      148  False  160000000   825532764                en      83.952
# 1      169  False  165000000   701729206                en     140.241
# 2      152  False  185000000  1004558444                en     130.643
#
# ...
